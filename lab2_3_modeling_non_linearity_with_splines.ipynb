# %%
# All imports go here

# %% [markdown]
# # Lab 2.3 - Modeling non-linear relationships with splines
#
# In this lab, we return to the topic of modeling non-linear relationships. We will practice working with `sklearn` pipelines, but this time replacing the polynomial features with splines.

# %% [markdown]
# ## Problem 1 - Visualize the relationships.
#
# **Task.**
#
# 1. Use `sns.lmplot()` to visualize the relationship between `MedianEarnings` and the numeric predictors as shown in the previous activity.
# 2. Comment on any non-linearity that you see in the relationships.

# %% [markdown]
# *Paste a screenshot here*
#
# <font color="orange">
# Write a summary of what you learned.
# </font>

# %% [markdown]
# ## Problem 2 - Load and split up the data.
#
# 1. Load the `college_earnings.csv` file using `polars`.
# 2. Split the data into a training and test set using `sklearn`'s `train_test_split()` function. Use a `random_state` of 42 and a `test_size` of 0.2.
# 3. Create X and y objects for the training and test sets.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 3 - Build your preprocessor
#
# 1. Use `make_pipeline` to make pipelines for each column type (e.g., missing data, missing data + non-linear, categorical features, etc.).  <font color="orange"><i>In this lab, use splines to model any non-linear relationships.</i></font>
# 2. Use `make_column_transformer` to combine your pipelines based on the column type.

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 4 - Make models
#
# Suppose that we want to use two learning methods, OLS and kNN, to make predictions.
#
# **Task.**
# 1. Make a model object for each learning method (OLS and kNN regressors).
# 2. Explore the parameters for each and create a grid of potential parameters. <font color="orange">Be sure to include the number of knots for the splines in the grid of parameters for each model.</font>
# 3. Use a `KFold` object to specify the resampling method for cross-validation and allow for proper comparison of the learning methods.
# 4. Create a grid search object that incorporates the cross-validation strategy for each learning method

# %%
# Your code here (add cells as needed)

# %% [markdown]
# ## Problem 5 - Perform the grid search and compare the learning methods.
#
# Now perform the grid search for each learning method and compare the CV MSE to determine which model performed the best.

# %%
# Your code here (add cells as needed)
